# %%
from google.colab import drive
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 from google.colab import drive
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
drive.mount('/content/gdrive')

# %%
import pandas as pd

# %%
DF = pd.read_csv("/content/gdrive/MyDrive/Datasets/pokemon_data.csv")
df = DF
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 DF = pd.read_csv("/content/gdrive/MyDrive/Datasets/pokemon_data.csv")
#       2 df = DF
#
# File C:\ProgramFiles\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df['Name'].head()
# df.Name
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
df[['Name', 'Type 1', 'Sp. Def', 'Speed']].head()
# Out:
#                     Name Type 1  Sp. Def  Speed
# 0              Bulbasaur  Grass       65     45
# 1                Ivysaur  Grass       80     60
# 2               Venusaur  Grass      100     80
# 3  VenusaurMega Venusaur  Grass      120     80
# 4             Charmander   Fire       50     65

# %%
# Do changes and see results
df.iloc[ 5 : 10, 5]
# Out:
# 5     64
# 6     84
# 7    130
# 8    104
# 9     48
# Name: Attack, dtype: int64

# %%
for index, row in df.iterrows():
  # print(index, row)
  print(index, row[['Name', 'Type 1']])
# Out:
# 0 Name      Bulbasaur
# Type 1        Grass
# Name: 0, dtype: object
# 1 Name      Ivysaur
# Type 1      Grass
# Name: 1, dtype: object
# 2 Name      Venusaur
# Type 1       Grass
# Name: 2, dtype: object
# 3 Name      VenusaurMega Venusaur
# Type 1                    Grass
# Name: 3, dtype: object
# 4 Name      Charmander
# Type 1          Fire
# Name: 4, dtype: object
# 5 Name      Charmeleon
# Type 1          Fire
# Name: 5, dtype: object
# 6 Name      Charizard
# Type 1         Fire
# Name: 6, dtype: object
# 7 Name      CharizardMega Charizard X
# Type 1                         Fire
# Name: 7, dtype: object
# 8 Name      CharizardMega Charizard Y
# Type 1                         Fire
# Name: 8, dtype: object
# 9 Name      Squirtle
# Type 1       Water
# Name: 9, dtype: object
# 10 Name      Wartortle
# Type 1        Water
# Name: 10, dtype: object
# 11 Name      Blastoise
# Type 1        Water
# Name: 11, dtype: object
# 12 Name      BlastoiseMega Blastoise
# ...

# %%
df.loc[df['Type 1'] == "Fire"].head()
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
#
#    Sp. Def  Speed  Generation  Legendary
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False
# 7       85    100           1      False
# 8      115    100           1      False

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values('Attack')
# Out:
#        #                     Name   Type 1    Type 2   HP  Attack  Defense  \
# 488  440                  Happiny   Normal       NaN  100       5        5
# 121  113                  Chansey   Normal       NaN  250       5        5
# 230  213                  Shuckle      Bug      Rock   20      10      230
# 261  242                  Blissey   Normal       NaN  255      10       10
# 139  129                 Magikarp    Water       NaN   20      10       55
# ..   ...                      ...      ...       ...  ...     ...      ...
# 429  386       DeoxysAttack Forme  Psychic       NaN   50     180       20
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 424  383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# 232  214  HeracrossMega Heracross      Bug  Fighting   80     185      115
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values('Attack',  ascending = False) # Actually print in descending order
# Out:
#        #                     Name   Type 1    Type 2   HP  Attack  Defense  \
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 232  214  HeracrossMega Heracross      Bug  Fighting   80     185      115
# 424  383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 429  386       DeoxysAttack Forme  Psychic       NaN   50     180       20
# ..   ...                      ...      ...       ...  ...     ...      ...
# 139  129                 Magikarp    Water       NaN   20      10       55
# 261  242                  Blissey   Normal       NaN  255      10       10
# 230  213                  Shuckle      Bug      Rock   20      10      230
# 121  113                  Chansey   Normal       NaN  250       5        5
# 488  440                  Happiny   Normal       NaN  100       5        5
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Name', 'Attack'],  ascending = [0, 1]) # 0 = Descedning , 1 = Ascending first one for first attribute and second one for Second attribute
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# Making changes to the data
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df['Total Of Attack and Defence'] = df['Attack'] + df['Defense'] 
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total Of Attack and Defence
# 0       65     45           1      False                           98
# 1       80     60           1      False                          125
# 2      100     80           1      False                          165
# 3      120     80           1      False                          223
# 4       50     65           1      False                           95

# %%
df = df.drop(columns = ['Total Of Attack and Defence']).head(5)
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df['Total'] = df.iloc[0: 4, 4 : 7 ].sum(axis = 1) # first 0 : 4 reperesents rows and 4 : 7 represents columns

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False  143.0
# 1       80     60           1      False  185.0
# 2      100     80           1      False  245.0
# 3      120     80           1      False  303.0
# 4       50     65           1      False    NaN

# %%
45 + 49 + 49
# Out:
# 143

# %%
cols = list(df.columns)
cols
# Out:
# ['#',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary',
#  'Total']

# %%
df.head(2)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
#
#    Generation  Legendary  Total
# 0           1      False  143.0
# 1           1      False  185.0

# %%
# Column index changing

df = df[cols[0 : 4]+ [cols[-1]] + cols[4 : 12]]

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison  143.0  45      49       49
# 1  2                Ivysaur  Grass  Poison  185.0  60      62       63
# 2  3               Venusaur  Grass  Poison  245.0  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison  303.0  80     100      123
# 4  4             Charmander   Fire     NaN    NaN  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
#saving our data(exporting into desired format)

# %%
df = DF

# %%
df[0 : 4]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary  Total Of Attack and Defence
# 0       65     45           1      False                           98
# 1       80     60           1      False                          125
# 2      100     80           1      False                          165
# 3      120     80           1      False                          223

# %%
# df.to_csv('Modified_Pokemon.csv', index = False) # index = False means it will delete the first numbering column from file
# df.to_excel('Modified_Pokemon.xlsx', index = False) # index = False means it will delete the first numbering column from file
# df.to_csv('Modified_Pokemon.txt', index = False, sep = '\t') # index = False means it will delete the first numbering column from file

# %%
# Filtering Data
df.loc[df['Type 1'] == 'Fire'].head(10)
# Out:
#      #                       Name Type 1  Type 2  HP  Attack  Defense  \
# 4    4                 Charmander   Fire     NaN  39      52       43
# 5    5                 Charmeleon   Fire     NaN  58      64       58
# 6    6                  Charizard   Fire  Flying  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying  78     104       78
# 42  37                     Vulpix   Fire     NaN  38      41       40
# 43  38                  Ninetales   Fire     NaN  73      76       75
# 63  58                  Growlithe   Fire     NaN  55      70       45
# 64  59                   Arcanine   Fire     NaN  90     110       80
# 83  77                     Ponyta   Fire     NaN  50      85       55
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary  \
# 4        60       50     65           1      False
# 5        80       65     80           1      False
# ...

# %%
df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Ice')]
# Out:
#        #                     Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 509  459                   Snover  Grass    Ice  60      62       50       62
# 510  460                Abomasnow  Grass    Ice  90      92       75       92
# 511  460  AbomasnowMega Abomasnow  Grass    Ice  90     132      105      132
#
#      Sp. Def  Speed  Generation  Legendary  Total Of Attack and Defence
# 509       60     40           4      False                          112
# 510       85     60           4      False                          167
# 511      105     30           4      False                          237

# %%
df.loc[(df['Type 1'] == 'Grass') | (df['Type 2'] == 'Ice')].head(10)
# Out:
#      #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0    1              Bulbasaur  Grass  Poison  45      49       49       65
# 1    2                Ivysaur  Grass  Poison  60      62       63       80
# 2    3               Venusaur  Grass  Poison  80      82       83      100
# 3    3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 48  43                 Oddish  Grass  Poison  45      50       55       75
# 49  44                  Gloom  Grass  Poison  60      65       70       85
# 50  45              Vileplume  Grass  Poison  75      80       85      110
# 75  69             Bellsprout  Grass  Poison  50      75       35       70
# 76  70             Weepinbell  Grass  Poison  65      90       50       85
# 77  71             Victreebel  Grass  Poison  80     105       65      100
#
#     Sp. Def  Speed  Generation  Legendary  Total Of Attack and Defence
# 0        65     45           1      False                           98
# ...

# %%
df.loc[((df['Type 1'] == 'Grass') | (df['Type 2'] == 'Ice')) & (df['HP'] >= 90)].head(10)
# Out:
#        #                     Name Type 1   Type 2   HP  Attack  Defense  \
# 94    87                  Dewgong  Water      Ice   90      70       80
# 111  103                Exeggutor  Grass  Psychic   95      95       85
# 142  131                   Lapras  Water      Ice  130      85       80
# 298  275                  Shiftry  Grass     Dark   90     100       60
# 390  357                  Tropius  Grass   Flying   99      68       83
# 434  389                 Torterra  Grass   Ground   95     109      105
# 510  460                Abomasnow  Grass      Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow  Grass      Ice   90     132      105
# 516  465                Tangrowth  Grass      NaN  100     100      125
# 550  492        ShayminLand Forme  Grass      NaN  100     100      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  \
# 94        70       95     70           1      False
# 111      125       65     55           1      False
# ...

# %%
new_df = df.loc[((df['Type 1'] == 'Grass') | (df['Type 2'] == 'Ice')) & (df['HP'] >= 90)].head(10)
new_df.to_csv('Filtererd.csv')

# %%
new_df.reset_index()
# Out:
#    index    #                     Name Type 1   Type 2   HP  Attack  Defense  \
# 0     94   87                  Dewgong  Water      Ice   90      70       80
# 1    111  103                Exeggutor  Grass  Psychic   95      95       85
# 2    142  131                   Lapras  Water      Ice  130      85       80
# 3    298  275                  Shiftry  Grass     Dark   90     100       60
# 4    390  357                  Tropius  Grass   Flying   99      68       83
# 5    434  389                 Torterra  Grass   Ground   95     109      105
# 6    510  460                Abomasnow  Grass      Ice   90      92       75
# 7    511  460  AbomasnowMega Abomasnow  Grass      Ice   90     132      105
# 8    516  465                Tangrowth  Grass      NaN  100     100      125
# 9    550  492        ShayminLand Forme  Grass      NaN  100     100      100
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total Of Attack and Defence
# ...

# %%
new_df.reset_index().drop(columns = ['index']) ### OR
# Out:
#      #                     Name Type 1   Type 2   HP  Attack  Defense  \
# 0   87                  Dewgong  Water      Ice   90      70       80
# 1  103                Exeggutor  Grass  Psychic   95      95       85
# 2  131                   Lapras  Water      Ice  130      85       80
# 3  275                  Shiftry  Grass     Dark   90     100       60
# 4  357                  Tropius  Grass   Flying   99      68       83
# 5  389                 Torterra  Grass   Ground   95     109      105
# 6  460                Abomasnow  Grass      Ice   90      92       75
# 7  460  AbomasnowMega Abomasnow  Grass      Ice   90     132      105
# 8  465                Tangrowth  Grass      NaN  100     100      125
# 9  492        ShayminLand Forme  Grass      NaN  100     100      100
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total Of Attack and Defence
# 0       70       95     70           1      False                          150
# ...

# %%
new_df.reset_index(drop = True, inplace = True) # this method is also been used as drop

# %%
new_df
# Out:
#      #                     Name Type 1   Type 2   HP  Attack  Defense  \
# 0   87                  Dewgong  Water      Ice   90      70       80
# 1  103                Exeggutor  Grass  Psychic   95      95       85
# 2  131                   Lapras  Water      Ice  130      85       80
# 3  275                  Shiftry  Grass     Dark   90     100       60
# 4  357                  Tropius  Grass   Flying   99      68       83
# 5  389                 Torterra  Grass   Ground   95     109      105
# 6  460                Abomasnow  Grass      Ice   90      92       75
# 7  460  AbomasnowMega Abomasnow  Grass      Ice   90     132      105
# 8  465                Tangrowth  Grass      NaN  100     100      125
# 9  492        ShayminLand Forme  Grass      NaN  100     100      100
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total Of Attack and Defence
# 0       70       95     70           1      False                          150
# ...

# %%
df.loc[((df['Type 1'] == 'Fire') | (df['Type 2'] == 'Dragon')) & (df['HP'] >= 90)].head(10)
# Out:
#        #                   Name    Type 1  Type 2   HP  Attack  Defense  \
# 64    59               Arcanine      Fire     NaN   90     110       80
# 158  146                Moltres      Fire  Flying   90     100       90
# 196  181  AmpharosMega Ampharos  Electric  Dragon   90      95      105
# 263  244                  Entei      Fire     NaN  115     115       85
# 270  250                  Ho-oh      Fire  Flying  106     130       90
# 540  483                 Dialga     Steel  Dragon  100     120      120
# 541  484                 Palkia     Water  Dragon   90     120      100
# 542  485                Heatran      Fire   Steel   91      90      106
# 544  487  GiratinaAltered Forme     Ghost  Dragon  150     100      120
# 545  487   GiratinaOrigin Forme     Ghost  Dragon  150     120      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  \
# 64       100       80     95           1      False
# 158      125       85     90           1       True
# ...

# %%
# names contains Mega
df[(df['Name'].str.contains('Mega'))].head(10)
# Out:
#        #                       Name   Type 1   Type 2   HP  Attack  Defense  \
# 3      3      VenusaurMega Venusaur    Grass   Poison   80     100      123
# 7      6  CharizardMega Charizard X     Fire   Dragon   78     130      111
# 8      6  CharizardMega Charizard Y     Fire   Flying   78     104       78
# 12     9    BlastoiseMega Blastoise    Water      NaN   79     103      120
# 19    15      BeedrillMega Beedrill      Bug   Poison   65     150       40
# 23    18        PidgeotMega Pidgeot   Normal   Flying   83      80       80
# 71    65      AlakazamMega Alakazam  Psychic      NaN   55      50       65
# 87    80        SlowbroMega Slowbro    Water  Psychic   95      75      180
# 102   94          GengarMega Gengar    Ghost   Poison   60      65       80
# 124  115  KangaskhanMega Kangaskhan   Normal      NaN  105     125      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  \
# 3        122      120     80           1      False
# ...

# %%
# not Mega
df[~(df['Name'].str.contains('Mega'))].head(10)
# Out:
#      #        Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0    1   Bulbasaur  Grass  Poison  45      49       49       65       65
# 1    2     Ivysaur  Grass  Poison  60      62       63       80       80
# 2    3    Venusaur  Grass  Poison  80      82       83      100      100
# 4    4  Charmander   Fire     NaN  39      52       43       60       50
# 5    5  Charmeleon   Fire     NaN  58      64       58       80       65
# 6    6   Charizard   Fire  Flying  78      84       78      109       85
# 9    7    Squirtle  Water     NaN  44      48       65       50       64
# 10   8   Wartortle  Water     NaN  59      63       80       65       80
# 11   9   Blastoise  Water     NaN  79      83      100       85      105
# 13  10    Caterpie    Bug     NaN  45      30       35       20       20
#
#     Speed  Generation  Legendary  Total Of Attack and Defence
# 0      45           1      False                           98
# ...

# %%
df.loc[(((df['Type 1'] == 'Grass') | (df['Type 2'] == 'Ice')) & (df['Generation'] >= 3)) & (df['Name'].str.contains('Mega'))].head(10)
# Out:
#        #                     Name Type 1  Type 2  HP  Attack  Defense  \
# 275  254    SceptileMega Sceptile  Grass  Dragon  70     110       75
# 511  460  AbomasnowMega Abomasnow  Grass     Ice  90     132      105
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  \
# 275      145       85    145           3      False
# 511      132      105     30           4      False
#
#      Total Of Attack and Defence
# 275                          185
# 511                          237

# %%
df[df['Type 1'].str.contains('Fire')].head(10)
# Out:
#      #                       Name Type 1  Type 2  HP  Attack  Defense  \
# 4    4                 Charmander   Fire     NaN  39      52       43
# 5    5                 Charmeleon   Fire     NaN  58      64       58
# 6    6                  Charizard   Fire  Flying  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying  78     104       78
# 42  37                     Vulpix   Fire     NaN  38      41       40
# 43  38                  Ninetales   Fire     NaN  73      76       75
# 63  58                  Growlithe   Fire     NaN  55      70       45
# 64  59                   Arcanine   Fire     NaN  90     110       80
# 83  77                     Ponyta   Fire     NaN  50      85       55
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary  \
# 4        60       50     65           1      False
# 5        80       65     80           1      False
# ...

# %%
import re

df[df['Type 1'].str.contains('Fire|Grass', regex = True)].head(10)
# Out:
#      #                       Name Type 1  Type 2  HP  Attack  Defense  \
# 0    1                  Bulbasaur  Grass  Poison  45      49       49
# 1    2                    Ivysaur  Grass  Poison  60      62       63
# 2    3                   Venusaur  Grass  Poison  80      82       83
# 3    3      VenusaurMega Venusaur  Grass  Poison  80     100      123
# 4    4                 Charmander   Fire     NaN  39      52       43
# 5    5                 Charmeleon   Fire     NaN  58      64       58
# 6    6                  Charizard   Fire  Flying  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying  78     104       78
# 42  37                     Vulpix   Fire     NaN  38      41       40
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary  \
# 0        65       65     45           1      False
# 1        80       80     60           1      False
# ...

# %%
df[df['Type 1'].str.contains('fire|grass|Ice', flags = re.I, regex = True)] # flags = re.I for case letter errors
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 4      4             Charmander   Fire     NaN   39      52       43       60
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 740  672                 Skiddo  Grass     NaN   66      65       48       62
# 741  673                 Gogoat  Grass     NaN  123     100       62       97
# 788  712               Bergmite    Ice     NaN   55      69       85       32
# 789  713                Avalugg    Ice     NaN   95     117      184       44
# 799  721              Volcanion   Fire   Water   80     110      120      130
#
# ...

# %%
df[df['Name'].str.contains('pi[a-z]*', flags = re.I, regex = True)].head(10) # * represents zero or more results
# Out:
#        #                 Name    Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 13    10             Caterpie       Bug     NaN  45      30       35       20
# 20    16               Pidgey    Normal  Flying  40      45       40       35
# 21    17            Pidgeotto    Normal  Flying  63      60       55       50
# 22    18              Pidgeot    Normal  Flying  83      80       75       70
# 23    18  PidgeotMega Pidgeot    Normal  Flying  83      80       80      135
# 30    25              Pikachu  Electric     NaN  35      55       40       50
# 42    37               Vulpix      Fire     NaN  38      41       40       50
# 76    70           Weepinbell     Grass  Poison  65      90       50       85
# 84    78             Rapidash      Fire     NaN  65     100       70       80
# 136  127               Pinsir       Bug     NaN  65     125      100       55
#
#      Sp. Def  Speed  Generation  Legendary  Total Of Attack and Defence
# ...

# %%
df[df['Name'].str.contains('^pi[a-z]*', flags = re.I, regex = True)] # ^ represents at start of letter
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 20    16               Pidgey    Normal    Flying   40      45       40
# 21    17            Pidgeotto    Normal    Flying   63      60       55
# 22    18              Pidgeot    Normal    Flying   83      80       75
# 23    18  PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25              Pikachu  Electric       NaN   35      55       40
# 136  127               Pinsir       Bug       NaN   65     125      100
# 137  127    PinsirMega Pinsir       Bug    Flying   65     155      120
# 186  172                Pichu  Electric       NaN   20      40       15
# 219  204               Pineco       Bug       NaN   50      65       90
# 239  221            Piloswine       Ice    Ground  100     100       80
# 438  393               Piplup     Water       NaN   53      51       53
# 558  499              Pignite      Fire  Fighting   90      93       55
# ...

# %%
# conditional changes

# %%
df.loc[df['Type 1'] == 'Fire', 'Type 1'] = 'Flamer'
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander   Flamer     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion   Flamer   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  \
# 0         65       65     45           1      False
# ...

# %%
df.loc[df['Type 1'] == 'Grass', 'Legendary'] = True
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander   Flamer     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion   Flamer   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  \
# 0         65       65     45           1       True
# ...

# %%
df.loc[df['Type 1'] == 'Grass', 'Legendary'] = False
df.head(10)
# Out:
#    #                       Name  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur   Grass  Poison  45      49       49       65
# 1  2                    Ivysaur   Grass  Poison  60      62       63       80
# 2  3                   Venusaur   Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur   Grass  Poison  80     100      123      122
# 4  4                 Charmander  Flamer     NaN  39      52       43       60
# 5  5                 Charmeleon  Flamer     NaN  58      64       58       80
# 6  6                  Charizard  Flamer  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X  Flamer  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y  Flamer  Flying  78     104       78      159
# 9  7                   Squirtle   Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary  Total Of Attack and Defence
# ...

# %%
# df.loc[df['Total Of Attack and Defence'] >= 160, ['Generation', 'Legendary']] = ['Achi', 'bhoot Achi']
# df

# %%
# Aggregate Statistics(group by)

# %%
df.groupby(['Type 1']).mean().sort_values('Attack', ascending = False)
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Fighting  363.851852  69.851852   96.777778   65.925926  53.111111  64.703704
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# Rock      392.727273  65.363636   92.863636  100.795455  63.340909  75.477273
# Steel     442.851852  65.222222   92.703704  126.370370  67.518519  80.629630
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# Flamer    327.403846  69.903846   84.769231   67.769231  88.980769  72.211538
# Flying    677.750000  70.750000   78.750000   66.250000  94.250000  72.500000
# Poison    251.785714  67.250000   74.678571   68.821429  60.428571  64.392857
# Water     303.089286  72.062500   74.151786   72.946429  74.812500  70.517857
# Ghost     486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# ...

# %%
df.groupby(['Type 1']).sum()
# Out:
#               #    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type 1
# Bug       23080  3925    4897     4880     3717     4471   4256         222
# Dark      14302  2071    2740     2177     2314     2155   2361         125
# Dragon    15180  2666    3588     2764     3099     2843   2657         124
# Electric  15994  2631    3040     2917     3961     3243   3718         144
# Fairy      7642  1260    1046     1117     1335     1440    826          70
# Fighting   9824  1886    2613     1780     1434     1747   1784          91
# Flamer    17025  3635    4408     3524     4627     3755   3871         167
# Flying     2711   283     315      265      377      290    410          22
# Ghost     15568  2062    2361     2598     2539     2447   2059         134
# Grass     24141  4709    5125     4956     5425     4930   4335         235
# Ground    11401  2361    3064     2715     1807     2008   2045         101
# ...

# %%
df.groupby(['Type 1']).count().sort_values(['Name'], ascending = False)
# Out:
#             #  Name  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Water     112   112      53  112     112      112      112      112    112
# Normal     98    98      37   98      98       98       98       98     98
# Grass      70    70      37   70      70       70       70       70     70
# Bug        69    69      52   69      69       69       69       69     69
# Psychic    57    57      19   57      57       57       57       57     57
# Flamer     52    52      24   52      52       52       52       52     52
# Electric   44    44      17   44      44       44       44       44     44
# Rock       44    44      35   44      44       44       44       44     44
# Ghost      32    32      22   32      32       32       32       32     32
# Ground     32    32      19   32      32       32       32       32     32
# Dragon     32    32      21   32      32       32       32       32     32
# ...

# %%
df.groupby(['Type 1', 'Type 2']).count()
# Out:
#                   #  Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1 Type 2
# Bug    Electric   2     2   2       2        2        2        2      2
#        Fighting   2     2   2       2        2        2        2      2
#        Fire       2     2   2       2        2        2        2      2
#        Flying    14    14  14      14       14       14       14     14
#        Ghost      1     1   1       1        1        1        1      1
# ...              ..   ...  ..     ...      ...      ...      ...    ...
# Water  Ice        3     3   3       3        3        3        3      3
#        Poison     3     3   3       3        3        3        3      3
#        Psychic    5     5   5       5        5        5        5      5
#        Rock       4     4   4       4        4        4        4      4
#        Steel      1     1   1       1        1        1        1      1
#
#                  Generation  Legendary  Total Of Attack and Defence
# Type 1 Type 2
# ...
